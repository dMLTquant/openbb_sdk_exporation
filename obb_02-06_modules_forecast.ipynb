# %% [markdown]
# # 02.06 Modules: Forecast
#
# > https://docs.openbb.co/sdk/guides/intros/forecast

# %%
from openbb_terminal.sdk import openbb
import pandas as pd

# %%
EURUSD = openbb.forex.load(
    from_symbol='EUR',
    to_symbol='USD',
    start_date = '2022-01-01',
    interval = '1day')

EURUSD.head(3)
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# date
# 2022-01-03  1.137385  1.137592  1.128541  1.137346   1.137346       0
# 2022-01-04  1.130199  1.132300  1.127345  1.130224   1.130224       0
# 2022-01-05  1.128541  1.134559  1.127764  1.128363   1.128363       0

# %%
EURUSD.head(5)
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# date
# 2022-01-03  1.137385  1.137592  1.128541  1.137346   1.137346       0
# 2022-01-04  1.130199  1.132300  1.127345  1.130224   1.130224       0
# 2022-01-05  1.128541  1.134559  1.127764  1.128363   1.128363       0
# 2022-01-06  1.131222  1.133067  1.128554  1.131350   1.131350       0
# 2022-01-07  1.129586  1.135976  1.129050  1.129688   1.129688       0

# %%
EURUSD.tail(1)
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# date
# 2022-11-30  1.033165  1.038206  1.032205  1.037452   1.037452       0

# %%
openbb.forecast.plot(data=EURUSD, columns = ['Adj Close'])

# %% [markdown]
# ## Theta

# %%
help(openbb.forecast.theta)
# Out:
# Help on Operation in module openbb_terminal.core.library.operation:
#
# <openbb_terminal.core.library.operation.Operation object>
#     Use 'forecast.theta_chart' to access the view.
#     Performs Theta forecasting
#         An implementation of the 4Theta method with configurable theta parameter.
#
#         https://unit8co.github.io/darts/generated_api/darts.models.forecasting.theta.html
#
#         Parameters
#         ----------
#         data : Union[pd.Series, np.ndarray]
#             Input data.
#         target_column: Optional[str]:
#             Target column to forecast. Defaults to "close".
#         seasonal: str
#             Seasonal component.  One of [N, A, M]
#             Defaults to MULTIPLICATIVE.
#         seasonal_periods: int
#             Number of seasonal periods in a year
#             If not set, inferred from frequency of the series.
#         n_predict: int
#             Number of days to forecast
#         start_window: float
# ...

# %%
openbb.forecast.theta_chart(data = EURUSD, target_column = 'Adj Close', n_predict= 10)
# Out:
#   0%|          | 0/33 [00:00<?, ?it/s]
# Theta Model obtains MAPE: 1.31%
#     Actual price: 1.04
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Datetime   ┃ Prediction ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 2022-12-01 │ 1.04       │
# ├────────────┼────────────┤
# │ 2022-12-02 │ 1.04       │
# ├────────────┼────────────┤
# │ 2022-12-05 │ 1.04       │
# ├────────────┼────────────┤
# │ 2022-12-06 │ 1.04       │
# ├────────────┼────────────┤
# │ 2022-12-07 │ 1.04       │
# ├────────────┼────────────┤
# │ 2022-12-08 │ 1.04       │
# ├────────────┼────────────┤
# │ 2022-12-09 │ 1.04       │
# ├────────────┼────────────┤
# │ 2022-12-12 │ 1.04       │
# ├────────────┼────────────┤
# │ 2022-12-13 │ 1.04       │
# ├────────────┼────────────┤
# │ 2022-12-14 │ 1.04       │
# └────────────┴────────────┘

# %% [markdown]
# ## regr_chart

# %%
openbb.forecast.regr_chart(EURUSD, target_column = 'Close')
# Out:
# Predicting Regression for 5 days
#   0%|          | 0/33 [00:00<?, ?it/s]
# Regression model obtains MAPE: 1.33%
#     Actual price: 1.04
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Datetime   ┃ Prediction ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 2022-12-01 │ 1.04       │
# ├────────────┼────────────┤
# │ 2022-12-02 │ 1.03       │
# ├────────────┼────────────┤
# │ 2022-12-05 │ 1.03       │
# ├────────────┼────────────┤
# │ 2022-12-06 │ 1.04       │
# ├────────────┼────────────┤
# │ 2022-12-07 │ 1.04       │
# └────────────┴────────────┘
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
