# %% [markdown]
# https://docs.openbb.co/sdk/guides/basics#passing-results-to-another-function

# %%
from openbb_terminal.sdk import openbb

# %%
openbb.stocks.ca.screener(similar = ['AAPL', 'NFLX', 'META', 'AMZN', 'MSFT', 'GOOGL', 'DIS', 'TSLA'], data_type = 'valuation')
# Out:
#   Ticker    Market Cap    P/E  Fwd P/E   PEG   P/S    P/B    P/C   P/FCF  \
# 0   AAPL  2.280750e+12  23.63    21.18  2.66  5.78  45.64  47.22   23.61
# 1   AMZN  9.489800e+11  86.67    55.99  3.33  1.89   6.96  16.18     NaN
# 2    DIS  1.697400e+11  54.74    17.88  2.16  2.05   1.89  13.10  109.44
# 3  GOOGL  1.227030e+12  19.69    18.28  2.20  4.35   4.93  10.55   19.62
# 4   META  2.863800e+11  10.37    13.92   NaN  2.42   2.35   6.86   10.88
# 5   MSFT  1.783630e+12  26.05    21.62  2.00  8.78  10.38  16.63   39.83
# 6   NFLX  1.230600e+11  26.51    26.79  4.56  3.91   6.09  20.13  171.64
# 7   TSLA  5.357100e+11  56.35    32.45  1.17  7.16  14.44  25.38   33.44
#
#    EPS this Y  EPS next Y  EPS past 5Y  EPS next 5Y  Sales past 5Y   Price  \
# 0       0.089      0.0898        0.216       0.0889          0.115  144.22
# 1       0.549      0.8239        0.676       0.2600          0.281   93.95
# 2       1.707      0.2928       -0.280       0.2534          0.039   95.69
# 3       0.914      0.1139        0.321       0.0895          0.233   96.05
# 4       0.364     -0.1407        0.316          NaN          0.337  108.78
# 5       0.198      0.1709        0.243       0.1301          0.155  241.76
# 6       0.813      0.0170        0.905       0.0582          0.275  281.17
# 7       6.692      0.3729        0.486       0.4809          0.504  182.92
#
#    Change      Volume
# 0 -0.0263  69346520.0
# 1  0.0058  75062320.0
# 2 -0.0322  13668653.0
# 3 -0.0145  26252432.0
# 4 -0.0236  23332816.0
# 5 -0.0232  24810272.0
# 6 -0.0153   4707049.0
# 7  0.0003  93038144.0

# %%
symbols = openbb.etf.holdings('DIA')
dia_symbols = list(symbols.index.drop(['N/A']))
dia_valuation = openbb.stocks.ca.screener(similar = dia_symbols, data_type = 'valuation')
dia_valuation = dia_valuation.sort_values(by = ['Price'], ascending = False).convert_dtypes()

dia_valuation.head(5)
# Out:
#    Ticker      Market Cap    P/E  Fwd P/E   PEG   P/S     P/B    P/C   P/FCF  \
# 25    UNH  491110000000.0  26.07    21.34  1.83  1.56    6.67  12.64   19.25
# 10     GS  128680000000.0  10.18    10.21  <NA>  2.09    1.24   0.45    2.99
# 11     HD  329910000000.0  19.22    18.84  1.22   2.1  251.12  134.0  127.67
# 1    AMGN  152740000000.0  22.64    15.23  3.43   5.8   41.38  13.31   31.49
# 18    MCD  200950000000.0  34.37    26.09  5.15  8.64    <NA>  71.05  117.62
#
#     EPS this Y  EPS next Y  EPS past 5Y  EPS next 5Y  Sales past 5Y   Price  \
# 25       0.128      0.1321        0.201       0.1422          0.092  532.27
# 10       1.403      0.0952        0.296      -0.0912          0.113  382.36
# 11       0.301      0.0155        0.192        0.157          0.098  318.92
# 1       -0.165      0.0507        0.001        0.066          0.025  282.62
# 18       0.591      0.0513         0.13       0.0667         -0.012  272.88
#
#     Change   Volume
# 25   -0.01  2702268
# 10 -0.0167  2232764
# 11 -0.0229  4735507
# 1  -0.0039  2375954
# 18 -0.0077  3160615
